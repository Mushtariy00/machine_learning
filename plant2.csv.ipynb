# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import numpy as np
working_directory = os.getcwd()
print(working_directory)
# Out:
# /Users/mushtariy/pyprojects/Machine_Learning

# %%
path = '/Users/mushtariy/Downloads/plant.csv' # working_directory + '/plant.csv'

# %%
df = pd.read_csv(path)
df.head(10)
# Out:
#       AT      V       AP     RH      PE
# 0   8.34  40.77  1010.84  90.01  480.48
# 1  23.64  58.49  1011.40  74.20  445.75
# 2  29.74  56.90  1007.15  41.91  438.76
# 3  19.07  49.69  1007.22  76.79  453.09
# 4  11.80  40.66  1017.13  97.20  464.43
# 5  13.97  39.16  1016.05  84.60  470.96
# 6  22.10  71.29  1008.20  75.38  442.35
# 7  14.47  41.76  1021.98  78.41  464.00
# 8  31.25  69.51  1010.25  36.83  428.77
# 9   6.77  38.18  1017.80  81.13  484.31

# %%
x = df['V'].values
y = df['PE'].values

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 0)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(np.array(x_train).reshape(-1, 1), y_train)
# Out:
# LinearRegression()

# %%
xc_test = np.array(x_test).reshape(-1,1)
y_pred = model.predict(np.array(x_test).reshape(-1, 1))
print(y_pred)
# Out:
# [437.07598897 450.65477526 450.86493704 ... 460.33389292 446.75510663
#  434.14539966]

# %%
from sklearn.metrics import r2_score
r2_score(y_test, y_pred)
# Out:
# 0.762145775370183

# %%
plt.figure(figsize=(15,10))
plt.scatter(y_test, y_pred)
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Actual vs Predicted values')
plt.plot()
# Out:
# []
