# %% [markdown]
# Abdurakhmonova Mushtariy 201939183

# %% [markdown]
# ## Homework 2. Working with Iris dataset
# #### Using Iris.csv dataset:
#   1) read dataset based on pandas
#
#   2) dataset description
#
#   3) calculate missing values on the dataset
#
#   4) replace missing values
#
#   5) prepare a bar chart

# %% [markdown]
# ## Reading a dataset based on Pandas

# %%
import pandas as pd
df_iris = pd.read_csv('dataset/Iris.csv')

# %% [markdown]
# ## Dataset description

# %%
df_iris.loc[:]
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            NaN           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            NaN           NaN            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %% [markdown]
# Total number of data - 150
# Number of classes - 3
# - Iris-setosa
# - Iris-versicolo
# - Iris-virginica
#
# Number of features - 4
# - SepalLengthCm
# - SepalWidthCm
# - PetalLengthCm
# - PetalWidthCm

# %% [markdown]
# ## Calculating missing values on the dataset

# %% [markdown]
# #### Checking if there is a NaN values.

# %%
df_iris.isnull().values.any()
# Out:
# True

# %%
missing_values = df_iris.isnull().sum().sum()

# %%
print(f'Total missing values are: {missing_values}')
# Out:
# Total missing values are: 18

# %% [markdown]
# ## Replacing missing values

# %% [markdown]
# #### Replacing NaN values for single column

# %%
df_iris['SepalLengthCm'] = df_iris['SepalLengthCm'].fillna(0)

# %% [markdown]
# #### Checking if there is a NaN values in a 'SepalLengthCm' column.

# %%
df_iris['SepalLengthCm'].isnull().values.any()
# Out:
# False

# %% [markdown]
# #### Checking the number of NaN values

# %%
df_iris['SepalLengthCm'].isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# #### Replacing all NaN values with zeros(0)

# %%
df_iris = df_iris.fillna(0)

# %% [markdown]
# #### Checking if there is a NaN values.

# %%
df_iris.isnull().values.any()
# Out:
# False

# %%
print(df_iris.to_string())
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm          Species
# 0      1            5.1           3.5            1.4           0.2      Iris-setosa
# 1      2            4.9           3.0            1.4           0.2      Iris-setosa
# 2      3            4.7           3.2            1.3           0.2      Iris-setosa
# 3      4            4.6           3.1            1.5           0.2      Iris-setosa
# 4      5            5.0           3.6            0.0           0.2      Iris-setosa
# 5      6            5.4           3.9            1.7           0.4      Iris-setosa
# 6      7            4.6           3.4            1.4           0.3      Iris-setosa
# 7      8            5.0           3.4            1.5           0.2      Iris-setosa
# 8      9            4.4           2.9            1.4           0.2      Iris-setosa
# 9     10            0.0           0.0            1.5           0.1      Iris-setosa
# ...

# %% [markdown]
# ## Preparing a bar chart

# %%
df_iris.plot(kind = 'bar', y = ["SepalLengthCm","SepalWidthCm", "PetalLengthCm", 
              "PetalWidthCm", "Species"], title='Iris Dataset')
# Out:
# <AxesSubplot:title={'center':'Iris Dataset'}>

# %%
df_iris.plot(kind = 'area', y = ["SepalLengthCm","SepalWidthCm", "PetalLengthCm", 
              "PetalWidthCm", "Species"], title='Iris Dataset')
# Out:
# <AxesSubplot:title={'center':'Iris Dataset'}>
